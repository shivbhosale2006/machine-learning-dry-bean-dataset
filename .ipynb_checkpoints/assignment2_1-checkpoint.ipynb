# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
filename ='Dataset 1 - Dry Bean/Dry_Bean_dataset.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# min        1.024868      0.218951   20684.000000     161.243764      0.555315
# 25%        1.432307      0.715928   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764441   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.430306      0.911423  263261.000000     569.374358      0.866195
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000596
# min        0.919246      0.489618      0.640577      0.002778      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.990685      0.987303      0.010451      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643590      0.995063
# std        0.098996      0.004366
# min        0.410339      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.974767      0.999733

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df['Class'].value_counts()
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Area                 int64
# Perimeter          float64
# MajorAxisLength    float64
# MinorAxisLength    float64
# AspectRation       float64
# Eccentricity       float64
# ConvexArea           int64
# EquivDiameter      float64
# Extent             float64
# Solidity           float64
# roundness          float64
# Compactness        float64
# ShapeFactor1       float64
# ShapeFactor2       float64
# ShapeFactor3       float64
# ShapeFactor4       float64
# Class               object
# dtype: object

# %%
df['Class'] = df['Class'].astype('category')

# %%
df.duplicated().sum()
# Out:
# np.int64(68)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (13543, 17)

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(data=df,width=.5)
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()

# %%
num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    median = df[col].median()
    df.loc[(df[col] < lower) | (df[col] > upper), col] = median

# %%
df.shape
# Out:
# (13543, 17)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['Perimeter'],width=.5)
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['roundness'],width=.5)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['Compactness'],width=.5)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['Solidity'],width=.5)
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df['Extent'],width=.5)
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()

# %%
num_df = df.select_dtypes(include='number')
corr = num_df.corr()
plt.figure(figsize=(14, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
df.hist(figsize=(15,10))
plt.suptitle("Feature Distributions")
plt.show()

# %%
sns.countplot(x='Class', data=df)
plt.title("Class Distribution")
plt.xlabel("Bean Type")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(df['Area'], kde=True)
plt.title("Distribution of Area")
plt.xlabel("Area")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df['MajorAxisLength'], kde=True)
plt.title("Major Axis Length Distribution")
plt.show()

# %%
sns.histplot(df['MinorAxisLength'], kde=True)
plt.title("Major Axis Length Distribution")
plt.show()

# %%
sns.boxplot(x='Class', y='Area', data=df)
plt.title("Area distribution across classes")
plt.show()

# %%
sns.kdeplot(data=df, x='Area', hue='Class', fill=True)
plt.title("Density of Area across classes")
plt.show()

# %%
sns.kdeplot(data=df, x='Eccentricity', hue='Class', fill=True)
plt.title("Density of Area across classes")
plt.show()

# %%
sns.swarmplot(x='Class', y='roundness', data=df)
plt.title("Roundness across classes (Swarm Plot)")
plt.show()

# %%
sns.scatterplot(x='Area', y='Perimeter', hue='Class', data=df)
plt.title("Area vs Perimeter")
plt.show()

# %%
sns.scatterplot(x='Solidity', y='roundness', hue='Class', data=df)
plt.title("Solidity vs Roundness")
plt.show()

# %%
sns.scatterplot(x='EquivDiameter', y='ConvexArea', hue='Class', data=df)
plt.title("EquivDiameter vs ConcexArea")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = df.drop('Class',axis=1)
y= df['Class']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
X_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 2267   60736    985.501       342.445302       226.741776      1.510288
# 8403   43043    775.619       291.631415       188.391056      1.548011
# 6580   54672    931.865       386.653982       180.377848      1.549860
# 1685   44442    766.629       263.349682       215.203537      1.223724
# 138    33623    659.408       217.371862       197.083783      1.102941
# ...      ...        ...              ...              ...           ...
# 13191  38207    724.552       272.428590       179.157574      1.520609
# 3264   85890   1152.016       417.536420       262.719645      1.589285
# 9913   52042    855.807       324.418756       204.959834      1.582841
# 10867  28184    626.725       233.661158       153.984576      1.517432
# 2732   70344   1037.985       378.651095       237.909773      1.591574
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 2267       0.749393       61680     278.085377  0.789353  0.984695   0.785854
# 8403       0.763346       43508     234.102648  0.794973  0.989312   0.899116
# 6580       0.884516       55205     263.838118  0.721190  0.990345   0.791168
# 1685       0.576386       44827     237.876674  0.792645  0.991411   0.950239
# 138        0.763997       33918     206.906098  0.793238  0.991303   0.971713
# ...             ...         ...            ...       ...       ...        ...
# 13191      0.753340       38584     220.559886  0.737701  0.990229   0.914563
# 3264       0.777232       87188     330.694035  0.714654  0.985113   0.813271
# 9913       0.775151       52560     257.413932  0.725466  0.990145   0.892919
# 10867      0.752136       28504     189.433322  0.708586  0.988774   0.901692
# 2732       0.777964       71521     299.273725  0.821354  0.983543   0.820455
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 2267      0.812058      0.005638      0.001512      0.659438      0.995941
# 8403      0.802735      0.006775      0.001735      0.644383      0.997512
# 6580      0.682362      0.007072      0.000946      0.465618      0.998089
# 1685      0.903273      0.005926      0.002433      0.815902      0.998439
# 138       0.801514      0.006465      0.003274      0.642424      0.999292
# ...            ...           ...           ...           ...           ...
# 13191     0.809606      0.007130      0.001890      0.655462      0.996702
# 3264      0.792012      0.004861      0.001180      0.627284      0.996933
# 9913      0.793462      0.006234      0.001524      0.629582      0.996528
# 10867     0.810718      0.008291      0.002209      0.657264      0.997353
# 2732      0.790368      0.005383      0.001296      0.624682      0.994227
#
# [9480 rows x 16 columns]

# %%
y_train
# Out:
# 2267     BARBUNYA
# 8403         SIRA
# 6580        HOROZ
# 1685        SEKER
# 138         SEKER
#            ...
# 13191    DERMASON
# 3264     BARBUNYA
# 9913         SIRA
# 10867    DERMASON
# 2732     BARBUNYA
# Name: Class, Length: 9480, dtype: category
# Categories (7, object): ['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA']

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(20,weights='distance',p=1)
fit = clf.fit(X_train, y_train)
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array(['SIRA', 'SIRA', 'CALI', ..., 'BOMBAY', 'BARBUNYA', 'DERMASON'],
#       shape=(4063,), dtype=object)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pre)

# %%
print(cm)
# Out:
# [[196   0 125   0  54   0  17]
#  [  0 134   0   0   0   0   0]
#  [ 93   2 378   0  33   1   1]
#  [  0   0   0 970   0  40  62]
#  [ 25   0  21  15 416   0  87]
#  [  0   0   0  72   8 403  95]
#  [  0   5   0 102  46   8 654]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.62      0.50      0.56       392
#       BOMBAY       0.95      1.00      0.97       134
#         CALI       0.72      0.74      0.73       508
#     DERMASON       0.84      0.90      0.87      1072
#        HOROZ       0.75      0.74      0.74       564
#        SEKER       0.89      0.70      0.78       578
#         SIRA       0.71      0.80      0.76       815
#
#     accuracy                           0.78      4063
#    macro avg       0.78      0.77      0.77      4063
# weighted avg       0.78      0.78      0.77      4063

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
fit = clf.fit(X_train,y_train)
y_pre = fit.predict(X_test)

# %%
y_pre
# Out:
# array(['DERMASON', 'SIRA', 'CALI', ..., 'BOMBAY', 'BARBUNYA', 'DERMASON'],
#       shape=(4063,), dtype=object)

# %%
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.89      0.87      0.88       392
#       BOMBAY       1.00      1.00      1.00       134
#         CALI       0.88      0.92      0.90       508
#     DERMASON       0.90      0.88      0.89      1072
#        HOROZ       0.90      0.91      0.90       564
#        SEKER       0.90      0.93      0.91       578
#         SIRA       0.83      0.83      0.83       815
#
#     accuracy                           0.89      4063
#    macro avg       0.90      0.90      0.90      4063
# weighted avg       0.89      0.89      0.89      4063

# %%
clf = DecisionTreeClassifier(criterion ='entropy',max_depth = 10,splitter ='random')
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.89      0.81      0.85       392
#       BOMBAY       1.00      1.00      1.00       134
#         CALI       0.88      0.91      0.90       508
#     DERMASON       0.91      0.91      0.91      1072
#        HOROZ       0.94      0.92      0.93       564
#        SEKER       0.92      0.94      0.93       578
#         SIRA       0.84      0.84      0.84       815
#
#     accuracy                           0.90      4063
#    macro avg       0.91      0.91      0.91      4063
# weighted avg       0.90      0.90      0.90      4063
